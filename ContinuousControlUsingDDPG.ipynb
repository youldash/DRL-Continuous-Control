# %% [markdown]
# # Continuous Control (Using the DDPG Algorithm)
#
# ---
#
# You are welcome to use this coding environment to train your agent for the project. Follow the instructions below to get started!
#
# ### 1. Start the Environment
#
# Run the next code cell to install a few packages.  This line will take a few minutes to run!

# %%
# !pip -q install ./python
# Out:
# tensorflow 1.7.1 has requirement numpy>=1.13.3, but you'll have numpy 1.12.1 which is incompatible.
# ipython 6.5.0 has requirement prompt-toolkit<2.0.0,>=1.0.15, but you'll have prompt-toolkit 3.0.5 which is incompatible.

# %% [markdown]
# The environments corresponding to both versions of the environment are already saved in the Workspace and can be accessed at the file paths provided below.
#
# Please select one of the two options below for loading the environment.

# %%
# Imports.
import time
import random
import torch
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# High-resolution plots for retina displays.
# %config InlineBackend.figure_format = 'retina'

# Utility imports.
from itertools import count
from collections import deque

# Hide any deprecate warnings.
import warnings
warnings.filterwarnings("ignore")

# Agents interact with, and learns from environments.
from agent import Agent

# %load_ext autoreload
# %autoreload 2

# %%
# Unity environment.
from unityagents import UnityEnvironment

# Select this option to load version 1 (with a single agent) of the environment.
# env = UnityEnvironment(file_name='/data/Reacher_One_Linux_NoVis/Reacher_One_Linux_NoVis.x86_64')

# Select this option to load version 2 (with 20 agents) of the environment.
env = UnityEnvironment(file_name='/data/Reacher_Linux_NoVis/Reacher.x86_64')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_speed -> 1.0
# 		goal_size -> 5.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# Get the default brain.
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# #### Obtain NVidia GPU information

# %%
# Set the working device on the NVIDIA Tesla K80 accelerator GPU (depending on availability).
# Otherwise we use the CPU.
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', str(device).upper())
print()

# Log additional info (when using the NVIDIA Tesla K80 accelerator).
# See <https://www.nvidia.com/en-gb/data-center/tesla-k80/>.
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
# Out:
# Using device: CUDA
#
# Tesla K80
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# Run the code cell below to print some information about the environment.

# %%
# Reset the environment.
env_info = env.reset(train_mode=True)[brain_name]

# Number of agents.
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# Size of each action.
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# Examine the state space.
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 1
# Size of each action: 4
# There are 1 agents. Each observes a state with length: 33
# The state for the first agent looks like: [  0.00000000e+00  -4.00000000e+00   0.00000000e+00   1.00000000e+00
#   -0.00000000e+00  -0.00000000e+00  -4.37113883e-08   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00  -1.00000000e+01   0.00000000e+00
#    1.00000000e+00  -0.00000000e+00  -0.00000000e+00  -4.37113883e-08
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   5.75471878e+00  -1.00000000e+00
#    5.55726671e+00   0.00000000e+00   1.00000000e+00   0.00000000e+00
#   -1.68164849e-01]

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Note that **in this coding environment, you will not be able to watch the agents while they are training**, and you should set `train_mode=True` to restart the environment.

# %%
env_info = env.reset(train_mode=True)[brain_name]      # Reset the environment.
states = env_info.vector_observations                  # Get the current state (for each agent).
scores = np.zeros(num_agents)                          # Initialize the score (for each agent).
while True:
    actions = np.random.randn(num_agents, action_size) # Select an action (for each agent).
    actions = np.clip(actions, -1, 1)                  # All actions between -1 and 1.
    env_info = env.step(actions)[brain_name]           # Send all actions to tne environment.
    next_states = env_info.vector_observations         # Get next state (for each agent).
    rewards = env_info.rewards                         # Get reward (for each agent).
    dones = env_info.local_done                        # See if episode finished.
    scores += env_info.rewards                         # Update the score (for each agent).
    states = next_states                               # Roll over states to next time step.
    if np.any(dones):                                  # Exit loop if episode finished.
        break

print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))
# Out:
# Total score (averaged over agents) this episode: 0.0

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  A few **important notes**:
# - When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```
# - To structure your work, you're welcome to work directly in this Jupyter notebook, or you might like to start over with a new file!  You can see the list of files in the workspace by clicking on **_Jupyter_** in the top left corner of the notebook.
# - In this coding environment, you will not be able to watch the agents while they are training.  However, **_after training the agents_**, you can download the saved model weights to watch the agents on your own machine!

# %% [markdown]
# #### Define the Training Function

# %%
""" Global configuration.
"""
TOGGLE_PRIORITIZED_REPLAY = False  # True for the Prioritized Replay memory buffer.
TOGGLE_ADD_NOISE = True            # True for the Dueling Network (DN) method.
TOGGLE_GREEDY_ACTION = False       # True for the Double-DQN method. False for the fixed Q-target method.

# %%
# Get the parameters.
# state_size, action_size = brain.vector_observation_space_size, brain.vector_action_space_size

# %%
def ddpg(n_episodes=int(3e2), print_every=int(1e2)):
    """ Implementation of the Deep Deterministic Policy Gradient (DDPG) algorithm.
        See <https://spinningup.openai.com/en/latest/algorithms/ddpg.html>.
    
    Params
    ======
        n_episodes (int): Maximum number of training episodes
        print_every (int): Number of epochs to print after
    """

    # List containing scores from each episode.
    scores = []

    # Last (print_every) scores.
    scores_deque = deque(maxlen=print_every)
    
    # List containing scores from each episode.
    scores_window = []
    
    for i_episode in range(1, n_episodes+1):
        env_info = env.reset(train_mode=True)[brain_name]    # Reset the environment.
        states = env_info.vector_observations                # Get the current state (for each agent).
        scores = np.zeros(num_agents)                        # Initialize the score (for each agent).
        agent.reset()                                        # Reset the agent (and noise).
        tick = time.time()
        for i_step in count():
            actions = agent.act(states)
            env_info = env.step(actions)[brain_name]         # Send all actions to tne environment.
            next_states = env_info.vector_observations       # Get next state (for each agent).
            rewards = env_info.rewards                       # Get reward (for each agent).
            dones = env_info.local_done                      # See if episode finished.
            scores += env_info.rewards                       # Update the score (for each agent).
            
            for state, action, reward, next_state, done in zip(
                states, actions, rewards, next_states, dones):
                agent.step(state, action, reward, next_state, done)
            
            if i_step % print_every == 0:
                print('\rSTEP {:3.0f}\tAVG SCORE: {:.2f}'.format(i_step, np.mean(scores)), end="")
                        
            if np.any(dones):                                # Exit loop if the episode finished.
                break
            
            states = next_states                             # Roll over states to the next time step.
            
        # For a specified number of agents, use random sampling from the buffer to learn.
        agent.sample_and_learn()
        
        score = np.mean(scores)
        scores_deque.append(score)
        scores_window.append(score)

        print('\rEP {}\tμ LAST 100: {:.2f}\tμ CURRENT: {:.2f}\tMAX: {:.2f}\tMIN: {:.2f}\tLEN: {}\tTIME: {:.2f}'\
              .format(i_episode,
                      np.mean(scores_deque),
                      score,
                      np.max(scores),
                      np.min(scores),
                      len(agent.memory),
                      time.time()-tick),
              end="\n")
        
        if i_episode % 10 == 0:                              # Save every 10 episode.
            torch.save(agent.actor_local.state_dict(), 'models/checkpoint_actor.pth')
            torch.save(agent.critic_local.state_dict(), 'models/checkpoint_critic.pth')
            # print("Models saved successfully.")            
            
    # Return the scores.
    return scores_window

# %% [markdown]
# #### Create and Train the Agent

# %%
# Monitor training time (start time).
start_time = time.time()

# Initialize a DDPG agent instance.
agent = Agent(
    state_size=state_size, action_size=action_size, seed=0,
    prioritized_replay=TOGGLE_PRIORITIZED_REPLAY,
    add_noise=TOGGLE_ADD_NOISE,
    greedy_action=TOGGLE_GREEDY_ACTION)

# Now, we train the agent.
scores = ddpg()

# Monitor training time (end time).
end_time = (time.time()-start_time)/6e1

# Log the runtime.
print("\nSolved in {:.2f} minutes.".format(end_time))
# Out:
# EP 1	μ LAST 100: 0.00	μ CURRENT: 0.00	MAX: 0.00	MIN: 0.00	LEN: 1001	TIME: 3.10
# EP 2	μ LAST 100: 0.05	μ CURRENT: 0.11	MAX: 0.11	MIN: 0.11	LEN: 2002	TIME: 3.04
# EP 3	μ LAST 100: 0.05	μ CURRENT: 0.05	MAX: 0.05	MIN: 0.05	LEN: 3003	TIME: 3.06
# EP 4	μ LAST 100: 0.08	μ CURRENT: 0.16	MAX: 0.16	MIN: 0.16	LEN: 4004	TIME: 3.06
# EP 5	μ LAST 100: 0.14	μ CURRENT: 0.39	MAX: 0.39	MIN: 0.39	LEN: 5005	TIME: 3.05
# EP 6	μ LAST 100: 0.14	μ CURRENT: 0.14	MAX: 0.14	MIN: 0.14	LEN: 6006	TIME: 3.05
# EP 7	μ LAST 100: 0.26	μ CURRENT: 0.96	MAX: 0.96	MIN: 0.96	LEN: 7007	TIME: 3.08
# EP 8	μ LAST 100: 0.23	μ CURRENT: 0.00	MAX: 0.00	MIN: 0.00	LEN: 8008	TIME: 3.07
# EP 9	μ LAST 100: 0.33	μ CURRENT: 1.20	MAX: 1.20	MIN: 1.20	LEN: 9009	TIME: 3.05
# EP 10	μ LAST 100: 0.34	μ CURRENT: 0.42	MAX: 0.42	MIN: 0.42	LEN: 10010	TIME: 3.09
# EP 11	μ LAST 100: 0.38	μ CURRENT: 0.72	MAX: 0.72	MIN: 0.72	LEN: 11011	TIME: 3.05
# EP 12	μ LAST 100: 0.37	μ CURRENT: 0.25	MAX: 0.25	MIN: 0.25	LEN: 12012	TIME: 3.07
# EP 13	μ LAST 100: 0.36	μ CURRENT: 0.26	MAX: 0.26	MIN: 0.26	LEN: 13013	TIME: 3.11
# EP 14	μ LAST 100: 0.35	μ CURRENT: 0.31	MAX: 0.31	MIN: 0.31	LEN: 14014	TIME: 3.19
# EP 15	μ LAST 100: 0.43	μ CURRENT: 1.49	MAX: 1.49	MIN: 1.49	LEN: 15015	TIME: 3.16
# EP 16	μ LAST 100: 0.42	μ CURRENT: 0.24	MAX: 0.24	MIN: 0.24	LEN: 16016	TIME: 3.21
# EP 17	μ LAST 100: 0.46	μ CURRENT: 1.04	MAX: 1.04	MIN: 1.04	LEN: 17017	TIME: 3.15
# EP 18	μ LAST 100: 0.52	μ CURRENT: 1.56	MAX: 1.56	MIN: 1.56	LEN: 18018	TIME: 3.07
# EP 19	μ LAST 100: 0.51	μ CURRENT: 0.38	MAX: 0.38	MIN: 0.38	LEN: 19019	TIME: 3.19
# EP 20	μ LAST 100: 0.52	μ CURRENT: 0.71	MAX: 0.71	MIN: 0.71	LEN: 20020	TIME: 3.19
# EP 21	μ LAST 100: 0.50	μ CURRENT: 0.11	MAX: 0.11	MIN: 0.11	LEN: 21021	TIME: 3.32
# EP 22	μ LAST 100: 0.48	μ CURRENT: 0.08	MAX: 0.08	MIN: 0.08	LEN: 22022	TIME: 3.38
# EP 23	μ LAST 100: 0.48	μ CURRENT: 0.44	MAX: 0.44	MIN: 0.44	LEN: 23023	TIME: 3.15
# EP 24	μ LAST 100: 0.48	μ CURRENT: 0.46	MAX: 0.46	MIN: 0.46	LEN: 24024	TIME: 3.19
# EP 25	μ LAST 100: 0.46	μ CURRENT: 0.00	MAX: 0.00	MIN: 0.00	LEN: 25025	TIME: 3.16
# EP 26	μ LAST 100: 0.47	μ CURRENT: 0.82	MAX: 0.82	MIN: 0.82	LEN: 26026	TIME: 3.19
# EP 27	μ LAST 100: 0.46	μ CURRENT: 0.00	MAX: 0.00	MIN: 0.00	LEN: 27027	TIME: 3.15
# EP 28	μ LAST 100: 0.44	μ CURRENT: 0.00	MAX: 0.00	MIN: 0.00	LEN: 28028	TIME: 3.18
# EP 29	μ LAST 100: 0.45	μ CURRENT: 0.83	MAX: 0.83	MIN: 0.83	LEN: 29029	TIME: 3.17
# EP 30	μ LAST 100: 0.44	μ CURRENT: 0.09	MAX: 0.09	MIN: 0.09	LEN: 30030	TIME: 3.15
# EP 31	μ LAST 100: 0.43	μ CURRENT: 0.12	MAX: 0.12	MIN: 0.12	LEN: 31031	TIME: 3.18
# EP 32	μ LAST 100: 0.43	μ CURRENT: 0.50	MAX: 0.50	MIN: 0.50	LEN: 32032	TIME: 3.19
# EP 33	μ LAST 100: 0.42	μ CURRENT: 0.07	MAX: 0.07	MIN: 0.07	LEN: 33033	TIME: 3.18
# EP 34	μ LAST 100: 0.43	μ CURRENT: 0.66	MAX: 0.66	MIN: 0.66	LEN: 34034	TIME: 3.21
# EP 35	μ LAST 100: 0.42	μ CURRENT: 0.18	MAX: 0.18	MIN: 0.18	LEN: 35035	TIME: 3.18
# EP 36	μ LAST 100: 0.42	μ CURRENT: 0.54	MAX: 0.54	MIN: 0.54	LEN: 36036	TIME: 3.19
# EP 37	μ LAST 100: 0.42	μ CURRENT: 0.39	MAX: 0.39	MIN: 0.39	LEN: 37037	TIME: 3.21
# EP 38	μ LAST 100: 0.42	μ CURRENT: 0.22	MAX: 0.22	MIN: 0.22	LEN: 38038	TIME: 3.21
# EP 39	μ LAST 100: 0.43	μ CURRENT: 0.89	MAX: 0.89	MIN: 0.89	LEN: 39039	TIME: 3.21
# EP 40	μ LAST 100: 0.43	μ CURRENT: 0.43	MAX: 0.43	MIN: 0.43	LEN: 40040	TIME: 3.17
# EP 41	μ LAST 100: 0.42	μ CURRENT: 0.09	MAX: 0.09	MIN: 0.09	LEN: 41041	TIME: 3.22
# EP 42	μ LAST 100: 0.43	μ CURRENT: 0.66	MAX: 0.66	MIN: 0.66	LEN: 42042	TIME: 3.22
# EP 43	μ LAST 100: 0.42	μ CURRENT: 0.00	MAX: 0.00	MIN: 0.00	LEN: 43043	TIME: 3.21
# EP 44	μ LAST 100: 0.41	μ CURRENT: 0.00	MAX: 0.00	MIN: 0.00	LEN: 44044	TIME: 3.19
# EP 45	μ LAST 100: 0.40	μ CURRENT: 0.00	MAX: 0.00	MIN: 0.00	LEN: 45045	TIME: 3.19
# EP 46	μ LAST 100: 0.39	μ CURRENT: 0.00	MAX: 0.00	MIN: 0.00	LEN: 46046	TIME: 3.20
# EP 47	μ LAST 100: 0.38	μ CURRENT: 0.00	MAX: 0.00	MIN: 0.00	LEN: 47047	TIME: 3.19
# EP 48	μ LAST 100: 0.38	μ CURRENT: 0.32	MAX: 0.32	MIN: 0.32	LEN: 48048	TIME: 3.17
# EP 49	μ LAST 100: 0.38	μ CURRENT: 0.19	MAX: 0.19	MIN: 0.19	LEN: 49049	TIME: 3.12
# EP 50	μ LAST 100: 0.37	μ CURRENT: 0.00	MAX: 0.00	MIN: 0.00	LEN: 50050	TIME: 3.16
# EP 51	μ LAST 100: 0.36	μ CURRENT: 0.00	MAX: 0.00	MIN: 0.00	LEN: 51051	TIME: 3.17
# EP 52	μ LAST 100: 0.36	μ CURRENT: 0.11	MAX: 0.11	MIN: 0.11	LEN: 52052	TIME: 3.20
# EP 53	μ LAST 100: 0.35	μ CURRENT: 0.17	MAX: 0.17	MIN: 0.17	LEN: 53053	TIME: 3.17
# EP 54	μ LAST 100: 0.35	μ CURRENT: 0.00	MAX: 0.00	MIN: 0.00	LEN: 54054	TIME: 3.16
# EP 55	μ LAST 100: 0.34	μ CURRENT: 0.00	MAX: 0.00	MIN: 0.00	LEN: 55055	TIME: 3.20
# EP 56	μ LAST 100: 0.33	μ CURRENT: 0.00	MAX: 0.00	MIN: 0.00	LEN: 56056	TIME: 3.19
# EP 57	μ LAST 100: 0.33	μ CURRENT: 0.00	MAX: 0.00	MIN: 0.00	LEN: 57057	TIME: 3.19
# EP 58	μ LAST 100: 0.33	μ CURRENT: 0.38	MAX: 0.38	MIN: 0.38	LEN: 58058	TIME: 3.17
# EP 59	μ LAST 100: 0.33	μ CURRENT: 0.57	MAX: 0.57	MIN: 0.57	LEN: 59059	TIME: 3.19
# EP 60	μ LAST 100: 0.33	μ CURRENT: 0.00	MAX: 0.00	MIN: 0.00	LEN: 60060	TIME: 3.19
# EP 61	μ LAST 100: 0.33	μ CURRENT: 0.34	MAX: 0.34	MIN: 0.34	LEN: 61061	TIME: 3.14
# EP 62	μ LAST 100: 0.32	μ CURRENT: 0.08	MAX: 0.08	MIN: 0.08	LEN: 62062	TIME: 3.18
# EP 63	μ LAST 100: 0.32	μ CURRENT: 0.00	MAX: 0.00	MIN: 0.00	LEN: 63063	TIME: 3.21
# EP 64	μ LAST 100: 0.31	μ CURRENT: 0.00	MAX: 0.00	MIN: 0.00	LEN: 64064	TIME: 3.18
# EP 65	μ LAST 100: 0.31	μ CURRENT: 0.17	MAX: 0.17	MIN: 0.17	LEN: 65065	TIME: 3.20
# EP 66	μ LAST 100: 0.32	μ CURRENT: 0.84	MAX: 0.84	MIN: 0.84	LEN: 66066	TIME: 3.20
# EP 67	μ LAST 100: 0.32	μ CURRENT: 0.00	MAX: 0.00	MIN: 0.00	LEN: 67067	TIME: 3.18
# EP 68	μ LAST 100: 0.31	μ CURRENT: 0.00	MAX: 0.00	MIN: 0.00	LEN: 68068	TIME: 3.20
# EP 69	μ LAST 100: 0.31	μ CURRENT: 0.09	MAX: 0.09	MIN: 0.09	LEN: 69069	TIME: 3.19
# EP 70	μ LAST 100: 0.31	μ CURRENT: 0.71	MAX: 0.71	MIN: 0.71	LEN: 70070	TIME: 3.31
# EP 71	μ LAST 100: 0.31	μ CURRENT: 0.00	MAX: 0.00	MIN: 0.00	LEN: 71071	TIME: 3.45
# EP 72	μ LAST 100: 0.31	μ CURRENT: 0.19	MAX: 0.19	MIN: 0.19	LEN: 72072	TIME: 3.40
# EP 73	μ LAST 100: 0.31	μ CURRENT: 0.15	MAX: 0.15	MIN: 0.15	LEN: 73073	TIME: 3.28
# EP 74	μ LAST 100: 0.31	μ CURRENT: 0.89	MAX: 0.89	MIN: 0.89	LEN: 74074	TIME: 3.20
# EP 75	μ LAST 100: 0.33	μ CURRENT: 1.39	MAX: 1.39	MIN: 1.39	LEN: 75075	TIME: 3.19
# EP 76	μ LAST 100: 0.33	μ CURRENT: 0.33	MAX: 0.33	MIN: 0.33	LEN: 76076	TIME: 3.21
# EP 77	μ LAST 100: 0.33	μ CURRENT: 0.81	MAX: 0.81	MIN: 0.81	LEN: 77077	TIME: 3.18
# EP 78	μ LAST 100: 0.34	μ CURRENT: 0.77	MAX: 0.77	MIN: 0.77	LEN: 78078	TIME: 3.20
# EP 79	μ LAST 100: 0.34	μ CURRENT: 0.56	MAX: 0.56	MIN: 0.56	LEN: 79079	TIME: 3.22
# EP 80	μ LAST 100: 0.34	μ CURRENT: 0.06	MAX: 0.06	MIN: 0.06	LEN: 80080	TIME: 3.19
# EP 81	μ LAST 100: 0.35	μ CURRENT: 0.96	MAX: 0.96	MIN: 0.96	LEN: 81081	TIME: 3.22
# EP 82	μ LAST 100: 0.34	μ CURRENT: 0.09	MAX: 0.09	MIN: 0.09	LEN: 82082	TIME: 3.23
# EP 83	μ LAST 100: 0.35	μ CURRENT: 0.50	MAX: 0.50	MIN: 0.50	LEN: 83083	TIME: 3.21
# EP 84	μ LAST 100: 0.35	μ CURRENT: 0.97	MAX: 0.97	MIN: 0.97	LEN: 84084	TIME: 3.21
# EP 85	μ LAST 100: 0.35	μ CURRENT: 0.40	MAX: 0.40	MIN: 0.40	LEN: 85085	TIME: 3.17
# EP 86	μ LAST 100: 0.36	μ CURRENT: 0.59	MAX: 0.59	MIN: 0.59	LEN: 86086	TIME: 3.20
# EP 87	μ LAST 100: 0.36	μ CURRENT: 1.12	MAX: 1.12	MIN: 1.12	LEN: 87087	TIME: 3.21
# EP 88	μ LAST 100: 0.37	μ CURRENT: 0.89	MAX: 0.89	MIN: 0.89	LEN: 88088	TIME: 3.20
# EP 89	μ LAST 100: 0.37	μ CURRENT: 0.75	MAX: 0.75	MIN: 0.75	LEN: 89089	TIME: 3.20
# EP 90	μ LAST 100: 0.37	μ CURRENT: 0.00	MAX: 0.00	MIN: 0.00	LEN: 90090	TIME: 3.13
# EP 91	μ LAST 100: 0.37	μ CURRENT: 0.63	MAX: 0.63	MIN: 0.63	LEN: 91091	TIME: 3.11
# EP 92	μ LAST 100: 0.39	μ CURRENT: 1.73	MAX: 1.73	MIN: 1.73	LEN: 92092	TIME: 3.23
# EP 93	μ LAST 100: 0.40	μ CURRENT: 1.43	MAX: 1.43	MIN: 1.43	LEN: 93093	TIME: 3.20
# EP 94	μ LAST 100: 0.40	μ CURRENT: 0.33	MAX: 0.33	MIN: 0.33	LEN: 94094	TIME: 3.23
# EP 95	μ LAST 100: 0.42	μ CURRENT: 1.95	MAX: 1.95	MIN: 1.95	LEN: 95095	TIME: 3.22
# EP 96	μ LAST 100: 0.43	μ CURRENT: 2.29	MAX: 2.29	MIN: 2.29	LEN: 96096	TIME: 3.20
# EP 97	μ LAST 100: 0.46	μ CURRENT: 3.26	MAX: 3.26	MIN: 3.26	LEN: 97097	TIME: 3.22
# EP 98	μ LAST 100: 0.47	μ CURRENT: 0.99	MAX: 0.99	MIN: 0.99	LEN: 98098	TIME: 3.20
# EP 99	μ LAST 100: 0.47	μ CURRENT: 0.75	MAX: 0.75	MIN: 0.75	LEN: 99099	TIME: 3.20
# EP 100	μ LAST 100: 0.48	μ CURRENT: 1.54	MAX: 1.54	MIN: 1.54	LEN: 100100	TIME: 3.20
# EP 101	μ LAST 100: 0.50	μ CURRENT: 1.66	MAX: 1.66	MIN: 1.66	LEN: 101101	TIME: 3.21
# EP 102	μ LAST 100: 0.51	μ CURRENT: 1.51	MAX: 1.51	MIN: 1.51	LEN: 102102	TIME: 3.22
# EP 103	μ LAST 100: 0.52	μ CURRENT: 1.19	MAX: 1.19	MIN: 1.19	LEN: 103103	TIME: 3.20
# EP 104	μ LAST 100: 0.55	μ CURRENT: 2.35	MAX: 2.35	MIN: 2.35	LEN: 104104	TIME: 3.21
# EP 105	μ LAST 100: 0.55	μ CURRENT: 0.86	MAX: 0.86	MIN: 0.86	LEN: 105105	TIME: 3.19
# EP 106	μ LAST 100: 0.55	μ CURRENT: 0.41	MAX: 0.41	MIN: 0.41	LEN: 106106	TIME: 3.22
# EP 107	μ LAST 100: 0.55	μ CURRENT: 0.53	MAX: 0.53	MIN: 0.53	LEN: 107107	TIME: 3.23
# EP 108	μ LAST 100: 0.56	μ CURRENT: 0.94	MAX: 0.94	MIN: 0.94	LEN: 108108	TIME: 3.18
# EP 109	μ LAST 100: 0.57	μ CURRENT: 1.86	MAX: 1.86	MIN: 1.86	LEN: 109109	TIME: 3.21
# EP 110	μ LAST 100: 0.57	μ CURRENT: 1.01	MAX: 1.01	MIN: 1.01	LEN: 110110	TIME: 3.18
# EP 111	μ LAST 100: 0.59	μ CURRENT: 2.58	MAX: 2.58	MIN: 2.58	LEN: 111111	TIME: 3.22
# EP 112	μ LAST 100: 0.60	μ CURRENT: 1.04	MAX: 1.04	MIN: 1.04	LEN: 112112	TIME: 3.19
# EP 113	μ LAST 100: 0.60	μ CURRENT: 0.19	MAX: 0.19	MIN: 0.19	LEN: 113113	TIME: 3.17
# EP 114	μ LAST 100: 0.61	μ CURRENT: 1.25	MAX: 1.25	MIN: 1.25	LEN: 114114	TIME: 3.23
# EP 115	μ LAST 100: 0.60	μ CURRENT: 0.39	MAX: 0.39	MIN: 0.39	LEN: 115115	TIME: 3.23
# EP 116	μ LAST 100: 0.60	μ CURRENT: 0.64	MAX: 0.64	MIN: 0.64	LEN: 116116	TIME: 3.34
# EP 117	μ LAST 100: 0.59	μ CURRENT: 0.49	MAX: 0.49	MIN: 0.49	LEN: 117117	TIME: 3.43
# EP 118	μ LAST 100: 0.59	μ CURRENT: 1.36	MAX: 1.36	MIN: 1.36	LEN: 118118	TIME: 3.21
# EP 119	μ LAST 100: 0.60	μ CURRENT: 0.94	MAX: 0.94	MIN: 0.94	LEN: 119119	TIME: 3.18
# EP 120	μ LAST 100: 0.60	μ CURRENT: 0.46	MAX: 0.46	MIN: 0.46	LEN: 120120	TIME: 3.22
# EP 121	μ LAST 100: 0.60	μ CURRENT: 0.72	MAX: 0.72	MIN: 0.72	LEN: 121121	TIME: 3.22
# EP 122	μ LAST 100: 0.61	μ CURRENT: 0.71	MAX: 0.71	MIN: 0.71	LEN: 122122	TIME: 3.20
# EP 123	μ LAST 100: 0.61	μ CURRENT: 0.38	MAX: 0.38	MIN: 0.38	LEN: 123123	TIME: 3.22
# EP 124	μ LAST 100: 0.61	μ CURRENT: 0.72	MAX: 0.72	MIN: 0.72	LEN: 124124	TIME: 3.22
# EP 125	μ LAST 100: 0.61	μ CURRENT: 0.20	MAX: 0.20	MIN: 0.20	LEN: 125125	TIME: 3.22
# EP 126	μ LAST 100: 0.61	μ CURRENT: 0.60	MAX: 0.60	MIN: 0.60	LEN: 126126	TIME: 3.18
# EP 127	μ LAST 100: 0.61	μ CURRENT: 0.32	MAX: 0.32	MIN: 0.32	LEN: 127127	TIME: 3.21
# EP 128	μ LAST 100: 0.62	μ CURRENT: 0.94	MAX: 0.94	MIN: 0.94	LEN: 128128	TIME: 3.33
# EP 129	μ LAST 100: 0.62	μ CURRENT: 0.94	MAX: 0.94	MIN: 0.94	LEN: 129129	TIME: 3.18
# EP 130	μ LAST 100: 0.63	μ CURRENT: 0.49	MAX: 0.49	MIN: 0.49	LEN: 130130	TIME: 3.21
# EP 131	μ LAST 100: 0.64	μ CURRENT: 0.99	MAX: 0.99	MIN: 0.99	LEN: 131131	TIME: 3.21
# EP 132	μ LAST 100: 0.63	μ CURRENT: 0.29	MAX: 0.29	MIN: 0.29	LEN: 132132	TIME: 3.19
# EP 133	μ LAST 100: 0.64	μ CURRENT: 0.61	MAX: 0.61	MIN: 0.61	LEN: 133133	TIME: 3.23
# EP 134	μ LAST 100: 0.64	μ CURRENT: 1.23	MAX: 1.23	MIN: 1.23	LEN: 134134	TIME: 3.22
# EP 135	μ LAST 100: 0.66	μ CURRENT: 1.23	MAX: 1.23	MIN: 1.23	LEN: 135135	TIME: 3.21
# EP 136	μ LAST 100: 0.65	μ CURRENT: 0.46	MAX: 0.46	MIN: 0.46	LEN: 136136	TIME: 3.19
# EP 137	μ LAST 100: 0.66	μ CURRENT: 0.89	MAX: 0.89	MIN: 0.89	LEN: 137137	TIME: 3.23
# EP 138	μ LAST 100: 0.69	μ CURRENT: 3.05	MAX: 3.05	MIN: 3.05	LEN: 138138	TIME: 3.19
# EP 139	μ LAST 100: 0.68	μ CURRENT: 0.48	MAX: 0.48	MIN: 0.48	LEN: 139139	TIME: 3.21
# EP 140	μ LAST 100: 0.69	μ CURRENT: 1.06	MAX: 1.06	MIN: 1.06	LEN: 140140	TIME: 3.20
# EP 141	μ LAST 100: 0.70	μ CURRENT: 1.01	MAX: 1.01	MIN: 1.01	LEN: 141141	TIME: 3.22
# EP 142	μ LAST 100: 0.70	μ CURRENT: 1.16	MAX: 1.16	MIN: 1.16	LEN: 142142	TIME: 3.22
# EP 143	μ LAST 100: 0.72	μ CURRENT: 1.72	MAX: 1.72	MIN: 1.72	LEN: 143143	TIME: 3.21
# EP 144	μ LAST 100: 0.73	μ CURRENT: 1.09	MAX: 1.09	MIN: 1.09	LEN: 144144	TIME: 3.21
# EP 145	μ LAST 100: 0.73	μ CURRENT: 0.24	MAX: 0.24	MIN: 0.24	LEN: 145145	TIME: 3.23
# EP 146	μ LAST 100: 0.75	μ CURRENT: 1.09	MAX: 1.09	MIN: 1.09	LEN: 146146	TIME: 3.25
# EP 147	μ LAST 100: 0.76	μ CURRENT: 1.43	MAX: 1.43	MIN: 1.43	LEN: 147147	TIME: 3.21
# EP 148	μ LAST 100: 0.76	μ CURRENT: 0.76	MAX: 0.76	MIN: 0.76	LEN: 148148	TIME: 3.22
# EP 149	μ LAST 100: 0.77	μ CURRENT: 0.74	MAX: 0.74	MIN: 0.74	LEN: 149149	TIME: 3.21
# EP 150	μ LAST 100: 0.78	μ CURRENT: 0.62	MAX: 0.62	MIN: 0.62	LEN: 150150	TIME: 3.20
# EP 151	μ LAST 100: 0.79	μ CURRENT: 1.82	MAX: 1.82	MIN: 1.82	LEN: 151151	TIME: 3.21
# EP 152	μ LAST 100: 0.79	μ CURRENT: 0.09	MAX: 0.09	MIN: 0.09	LEN: 152152	TIME: 3.20
# EP 153	μ LAST 100: 0.80	μ CURRENT: 0.65	MAX: 0.65	MIN: 0.65	LEN: 153153	TIME: 3.22
# EP 154	μ LAST 100: 0.81	μ CURRENT: 1.45	MAX: 1.45	MIN: 1.45	LEN: 154154	TIME: 3.24
# EP 155	μ LAST 100: 0.82	μ CURRENT: 0.42	MAX: 0.42	MIN: 0.42	LEN: 155155	TIME: 3.23
# EP 156	μ LAST 100: 0.82	μ CURRENT: 0.73	MAX: 0.73	MIN: 0.73	LEN: 156156	TIME: 3.21
# EP 157	μ LAST 100: 0.83	μ CURRENT: 0.67	MAX: 0.67	MIN: 0.67	LEN: 157157	TIME: 3.24
# EP 158	μ LAST 100: 0.83	μ CURRENT: 0.00	MAX: 0.00	MIN: 0.00	LEN: 158158	TIME: 3.21
# EP 159	μ LAST 100: 0.83	μ CURRENT: 0.90	MAX: 0.90	MIN: 0.90	LEN: 159159	TIME: 3.22
# EP 160	μ LAST 100: 0.84	μ CURRENT: 0.81	MAX: 0.81	MIN: 0.81	LEN: 160160	TIME: 3.22
# EP 161	μ LAST 100: 0.84	μ CURRENT: 0.55	MAX: 0.55	MIN: 0.55	LEN: 161161	TIME: 3.19
# EP 162	μ LAST 100: 0.85	μ CURRENT: 1.15	MAX: 1.15	MIN: 1.15	LEN: 162162	TIME: 3.20
# EP 163	μ LAST 100: 0.86	μ CURRENT: 0.91	MAX: 0.91	MIN: 0.91	LEN: 163163	TIME: 3.20
# EP 164	μ LAST 100: 0.87	μ CURRENT: 0.45	MAX: 0.45	MIN: 0.45	LEN: 164164	TIME: 3.20
# EP 165	μ LAST 100: 0.88	μ CURRENT: 1.93	MAX: 1.93	MIN: 1.93	LEN: 165165	TIME: 3.20
# EP 166	μ LAST 100: 0.89	μ CURRENT: 1.99	MAX: 1.99	MIN: 1.99	LEN: 166166	TIME: 3.24
# EP 167	μ LAST 100: 0.92	μ CURRENT: 2.08	MAX: 2.08	MIN: 2.08	LEN: 167167	TIME: 3.41
# EP 168	μ LAST 100: 0.93	μ CURRENT: 1.11	MAX: 1.11	MIN: 1.11	LEN: 168168	TIME: 3.46
# EP 169	μ LAST 100: 0.93	μ CURRENT: 0.87	MAX: 0.87	MIN: 0.87	LEN: 169169	TIME: 3.37
# EP 170	μ LAST 100: 0.94	μ CURRENT: 0.95	MAX: 0.95	MIN: 0.95	LEN: 170170	TIME: 3.21
# EP 171	μ LAST 100: 0.94	μ CURRENT: 0.18	MAX: 0.18	MIN: 0.18	LEN: 171171	TIME: 3.21
# EP 172	μ LAST 100: 0.95	μ CURRENT: 0.99	MAX: 0.99	MIN: 0.99	LEN: 172172	TIME: 3.22
# EP 173	μ LAST 100: 0.95	μ CURRENT: 0.48	MAX: 0.48	MIN: 0.48	LEN: 173173	TIME: 3.27
# EP 174	μ LAST 100: 0.96	μ CURRENT: 2.00	MAX: 2.00	MIN: 2.00	LEN: 174174	TIME: 3.26
# EP 175	μ LAST 100: 0.95	μ CURRENT: 0.70	MAX: 0.70	MIN: 0.70	LEN: 175175	TIME: 3.24
# EP 176	μ LAST 100: 0.96	μ CURRENT: 0.45	MAX: 0.45	MIN: 0.45	LEN: 176176	TIME: 3.21
# EP 177	μ LAST 100: 0.95	μ CURRENT: 0.10	MAX: 0.10	MIN: 0.10	LEN: 177177	TIME: 3.21
# EP 178	μ LAST 100: 0.95	μ CURRENT: 0.69	MAX: 0.69	MIN: 0.69	LEN: 178178	TIME: 3.22
# EP 179	μ LAST 100: 0.95	μ CURRENT: 0.99	MAX: 0.99	MIN: 0.99	LEN: 179179	TIME: 3.23
# EP 180	μ LAST 100: 0.95	μ CURRENT: 0.28	MAX: 0.28	MIN: 0.28	LEN: 180180	TIME: 3.22
# EP 181	μ LAST 100: 0.95	μ CURRENT: 1.05	MAX: 1.05	MIN: 1.05	LEN: 181181	TIME: 3.19
# EP 182	μ LAST 100: 0.96	μ CURRENT: 0.43	MAX: 0.43	MIN: 0.43	LEN: 182182	TIME: 3.20
# EP 183	μ LAST 100: 0.96	μ CURRENT: 0.32	MAX: 0.32	MIN: 0.32	LEN: 183183	TIME: 3.17
# EP 184	μ LAST 100: 0.96	μ CURRENT: 1.09	MAX: 1.09	MIN: 1.09	LEN: 184184	TIME: 3.20
# EP 185	μ LAST 100: 0.96	μ CURRENT: 1.13	MAX: 1.13	MIN: 1.13	LEN: 185185	TIME: 3.22
# EP 186	μ LAST 100: 0.98	μ CURRENT: 2.06	MAX: 2.06	MIN: 2.06	LEN: 186186	TIME: 3.22
# EP 187	μ LAST 100: 0.98	μ CURRENT: 0.76	MAX: 0.76	MIN: 0.76	LEN: 187187	TIME: 3.23
# EP 188	μ LAST 100: 0.98	μ CURRENT: 1.35	MAX: 1.35	MIN: 1.35	LEN: 188188	TIME: 3.22
# EP 189	μ LAST 100: 0.98	μ CURRENT: 0.67	MAX: 0.67	MIN: 0.67	LEN: 189189	TIME: 3.24
# EP 190	μ LAST 100: 0.99	μ CURRENT: 1.09	MAX: 1.09	MIN: 1.09	LEN: 190190	TIME: 3.25
# EP 191	μ LAST 100: 1.00	μ CURRENT: 1.22	MAX: 1.22	MIN: 1.22	LEN: 191191	TIME: 3.27
# EP 192	μ LAST 100: 0.99	μ CURRENT: 1.44	MAX: 1.44	MIN: 1.44	LEN: 192192	TIME: 3.25
# EP 193	μ LAST 100: 1.00	μ CURRENT: 1.67	MAX: 1.67	MIN: 1.67	LEN: 193193	TIME: 3.63
# EP 194	μ LAST 100: 1.00	μ CURRENT: 1.07	MAX: 1.07	MIN: 1.07	LEN: 194194	TIME: 3.24
# EP 195	μ LAST 100: 0.99	μ CURRENT: 0.66	MAX: 0.66	MIN: 0.66	LEN: 195195	TIME: 3.24
# EP 196	μ LAST 100: 0.97	μ CURRENT: 0.62	MAX: 0.62	MIN: 0.62	LEN: 196196	TIME: 3.25
# EP 197	μ LAST 100: 0.94	μ CURRENT: 0.37	MAX: 0.37	MIN: 0.37	LEN: 197197	TIME: 3.23
# EP 198	μ LAST 100: 0.94	μ CURRENT: 0.73	MAX: 0.73	MIN: 0.73	LEN: 198198	TIME: 3.23
# EP 199	μ LAST 100: 0.94	μ CURRENT: 0.88	MAX: 0.88	MIN: 0.88	LEN: 199199	TIME: 3.24
# EP 200	μ LAST 100: 0.94	μ CURRENT: 0.82	MAX: 0.82	MIN: 0.82	LEN: 200200	TIME: 3.24
# EP 201	μ LAST 100: 0.92	μ CURRENT: 0.37	MAX: 0.37	MIN: 0.37	LEN: 201201	TIME: 3.22
# EP 202	μ LAST 100: 0.92	μ CURRENT: 0.72	MAX: 0.72	MIN: 0.72	LEN: 202202	TIME: 3.24
# EP 203	μ LAST 100: 0.92	μ CURRENT: 1.16	MAX: 1.16	MIN: 1.16	LEN: 203203	TIME: 3.19
# EP 204	μ LAST 100: 0.90	μ CURRENT: 1.16	MAX: 1.16	MIN: 1.16	LEN: 204204	TIME: 3.16
# EP 205	μ LAST 100: 0.90	μ CURRENT: 0.27	MAX: 0.27	MIN: 0.27	LEN: 205205	TIME: 3.18
# EP 206	μ LAST 100: 0.90	μ CURRENT: 0.34	MAX: 0.34	MIN: 0.34	LEN: 206206	TIME: 3.23
# EP 207	μ LAST 100: 0.90	μ CURRENT: 1.15	MAX: 1.15	MIN: 1.15	LEN: 207207	TIME: 3.21
# EP 208	μ LAST 100: 0.90	μ CURRENT: 1.13	MAX: 1.13	MIN: 1.13	LEN: 208208	TIME: 3.20
# EP 209	μ LAST 100: 0.89	μ CURRENT: 0.68	MAX: 0.68	MIN: 0.68	LEN: 209209	TIME: 3.25
# EP 210	μ LAST 100: 0.89	μ CURRENT: 0.88	MAX: 0.88	MIN: 0.88	LEN: 210210	TIME: 3.35
# EP 211	μ LAST 100: 0.89	μ CURRENT: 2.19	MAX: 2.19	MIN: 2.19	LEN: 211211	TIME: 3.91
# EP 212	μ LAST 100: 0.89	μ CURRENT: 1.11	MAX: 1.11	MIN: 1.11	LEN: 212212	TIME: 3.34
# EP 213	μ LAST 100: 0.89	μ CURRENT: 0.56	MAX: 0.56	MIN: 0.56	LEN: 213213	TIME: 3.17
# EP 214	μ LAST 100: 0.88	μ CURRENT: 0.34	MAX: 0.34	MIN: 0.34	LEN: 214214	TIME: 3.15
# EP 215	μ LAST 100: 0.89	μ CURRENT: 1.02	MAX: 1.02	MIN: 1.02	LEN: 215215	TIME: 3.21
# EP 216	μ LAST 100: 0.89	μ CURRENT: 0.85	MAX: 0.85	MIN: 0.85	LEN: 216216	TIME: 3.28
# EP 217	μ LAST 100: 0.90	μ CURRENT: 0.84	MAX: 0.84	MIN: 0.84	LEN: 217217	TIME: 3.18
# EP 218	μ LAST 100: 0.89	μ CURRENT: 1.23	MAX: 1.23	MIN: 1.23	LEN: 218218	TIME: 3.15
# EP 219	μ LAST 100: 0.89	μ CURRENT: 1.00	MAX: 1.00	MIN: 1.00	LEN: 219219	TIME: 3.19
# EP 220	μ LAST 100: 0.91	μ CURRENT: 1.57	MAX: 1.57	MIN: 1.57	LEN: 220220	TIME: 3.13
# EP 221	μ LAST 100: 0.91	μ CURRENT: 0.93	MAX: 0.93	MIN: 0.93	LEN: 221221	TIME: 3.22
# EP 222	μ LAST 100: 0.91	μ CURRENT: 1.14	MAX: 1.14	MIN: 1.14	LEN: 222222	TIME: 3.26
# EP 223	μ LAST 100: 0.93	μ CURRENT: 2.05	MAX: 2.05	MIN: 2.05	LEN: 223223	TIME: 3.24
# EP 224	μ LAST 100: 0.93	μ CURRENT: 1.28	MAX: 1.28	MIN: 1.28	LEN: 224224	TIME: 3.23
# EP 225	μ LAST 100: 0.94	μ CURRENT: 1.12	MAX: 1.12	MIN: 1.12	LEN: 225225	TIME: 3.25
# EP 226	μ LAST 100: 0.95	μ CURRENT: 0.91	MAX: 0.91	MIN: 0.91	LEN: 226226	TIME: 3.23
# EP 227	μ LAST 100: 0.95	μ CURRENT: 0.52	MAX: 0.52	MIN: 0.52	LEN: 227227	TIME: 3.26
# EP 228	μ LAST 100: 0.97	μ CURRENT: 3.10	MAX: 3.10	MIN: 3.10	LEN: 228228	TIME: 3.24
# EP 229	μ LAST 100: 0.97	μ CURRENT: 0.56	MAX: 0.56	MIN: 0.56	LEN: 229229	TIME: 3.25
# EP 230	μ LAST 100: 0.97	μ CURRENT: 0.74	MAX: 0.74	MIN: 0.74	LEN: 230230	TIME: 3.23
# EP 231	μ LAST 100: 0.97	μ CURRENT: 1.03	MAX: 1.03	MIN: 1.03	LEN: 231231	TIME: 3.25
# EP 232	μ LAST 100: 0.97	μ CURRENT: 0.00	MAX: 0.00	MIN: 0.00	LEN: 232232	TIME: 3.25
# EP 233	μ LAST 100: 0.98	μ CURRENT: 1.58	MAX: 1.58	MIN: 1.58	LEN: 233233	TIME: 3.21
# EP 234	μ LAST 100: 0.97	μ CURRENT: 0.60	MAX: 0.60	MIN: 0.60	LEN: 234234	TIME: 3.14
# EP 235	μ LAST 100: 0.97	μ CURRENT: 1.72	MAX: 1.72	MIN: 1.72	LEN: 235235	TIME: 3.18
# EP 236	μ LAST 100: 0.98	μ CURRENT: 0.95	MAX: 0.95	MIN: 0.95	LEN: 236236	TIME: 3.20
# EP 237	μ LAST 100: 0.99	μ CURRENT: 2.35	MAX: 2.35	MIN: 2.35	LEN: 237237	TIME: 3.11
# EP 238	μ LAST 100: 0.97	μ CURRENT: 0.84	MAX: 0.84	MIN: 0.84	LEN: 238238	TIME: 3.14
# EP 239	μ LAST 100: 0.98	μ CURRENT: 1.43	MAX: 1.43	MIN: 1.43	LEN: 239239	TIME: 3.13
# EP 240	μ LAST 100: 0.97	μ CURRENT: 0.30	MAX: 0.30	MIN: 0.30	LEN: 240240	TIME: 3.14
# EP 241	μ LAST 100: 0.97	μ CURRENT: 0.52	MAX: 0.52	MIN: 0.52	LEN: 241241	TIME: 3.23
# EP 242	μ LAST 100: 0.96	μ CURRENT: 0.24	MAX: 0.24	MIN: 0.24	LEN: 242242	TIME: 3.16
# EP 243	μ LAST 100: 0.95	μ CURRENT: 0.77	MAX: 0.77	MIN: 0.77	LEN: 243243	TIME: 3.15
# EP 244	μ LAST 100: 0.95	μ CURRENT: 1.18	MAX: 1.18	MIN: 1.18	LEN: 244244	TIME: 3.11
# EP 245	μ LAST 100: 0.95	μ CURRENT: 0.00	MAX: 0.00	MIN: 0.00	LEN: 245245	TIME: 3.14
# EP 246	μ LAST 100: 0.95	μ CURRENT: 1.51	MAX: 1.51	MIN: 1.51	LEN: 246246	TIME: 3.18
# EP 247	μ LAST 100: 0.94	μ CURRENT: 0.46	MAX: 0.46	MIN: 0.46	LEN: 247247	TIME: 3.16
# EP 248	μ LAST 100: 0.94	μ CURRENT: 0.66	MAX: 0.66	MIN: 0.66	LEN: 248248	TIME: 3.12
# EP 249	μ LAST 100: 0.94	μ CURRENT: 0.17	MAX: 0.17	MIN: 0.17	LEN: 249249	TIME: 3.15
# EP 250	μ LAST 100: 0.94	μ CURRENT: 0.96	MAX: 0.96	MIN: 0.96	LEN: 250250	TIME: 3.18
# EP 251	μ LAST 100: 0.93	μ CURRENT: 0.40	MAX: 0.40	MIN: 0.40	LEN: 251251	TIME: 3.20
# EP 252	μ LAST 100: 0.92	μ CURRENT: 0.00	MAX: 0.00	MIN: 0.00	LEN: 252252	TIME: 3.11
# EP 253	μ LAST 100: 0.93	μ CURRENT: 0.99	MAX: 0.99	MIN: 0.99	LEN: 253253	TIME: 3.12
# EP 254	μ LAST 100: 0.92	μ CURRENT: 0.35	MAX: 0.35	MIN: 0.35	LEN: 254254	TIME: 3.10
# EP 255	μ LAST 100: 0.92	μ CURRENT: 0.35	MAX: 0.35	MIN: 0.35	LEN: 255255	TIME: 3.12
# EP 256	μ LAST 100: 0.92	μ CURRENT: 1.14	MAX: 1.14	MIN: 1.14	LEN: 256256	TIME: 3.09
# EP 257	μ LAST 100: 0.92	μ CURRENT: 0.86	MAX: 0.86	MIN: 0.86	LEN: 257257	TIME: 3.16
# EP 258	μ LAST 100: 0.93	μ CURRENT: 0.57	MAX: 0.57	MIN: 0.57	LEN: 258258	TIME: 3.13
# EP 259	μ LAST 100: 0.93	μ CURRENT: 0.71	MAX: 0.71	MIN: 0.71	LEN: 259259	TIME: 3.10
# EP 260	μ LAST 100: 0.92	μ CURRENT: 0.34	MAX: 0.34	MIN: 0.34	LEN: 260260	TIME: 3.18
# EP 261	μ LAST 100: 0.93	μ CURRENT: 1.22	MAX: 1.22	MIN: 1.22	LEN: 261261	TIME: 3.14
# EP 262	μ LAST 100: 0.92	μ CURRENT: 0.77	MAX: 0.77	MIN: 0.77	LEN: 262262	TIME: 3.38
# EP 263	μ LAST 100: 0.92	μ CURRENT: 0.00	MAX: 0.00	MIN: 0.00	LEN: 263263	TIME: 3.30
# EP 264	μ LAST 100: 0.92	μ CURRENT: 0.78	MAX: 0.78	MIN: 0.78	LEN: 264264	TIME: 3.38
# EP 265	μ LAST 100: 0.92	μ CURRENT: 2.12	MAX: 2.12	MIN: 2.12	LEN: 265265	TIME: 3.37
# EP 266	μ LAST 100: 0.91	μ CURRENT: 0.54	MAX: 0.54	MIN: 0.54	LEN: 266266	TIME: 3.17
# EP 267	μ LAST 100: 0.90	μ CURRENT: 1.48	MAX: 1.48	MIN: 1.48	LEN: 267267	TIME: 3.14
# EP 268	μ LAST 100: 0.89	μ CURRENT: 0.19	MAX: 0.19	MIN: 0.19	LEN: 268268	TIME: 3.16
# EP 269	μ LAST 100: 0.89	μ CURRENT: 0.54	MAX: 0.54	MIN: 0.54	LEN: 269269	TIME: 3.19
# EP 270	μ LAST 100: 0.88	μ CURRENT: 0.30	MAX: 0.30	MIN: 0.30	LEN: 270270	TIME: 3.23
# EP 271	μ LAST 100: 0.89	μ CURRENT: 1.07	MAX: 1.07	MIN: 1.07	LEN: 271271	TIME: 3.15
# EP 272	μ LAST 100: 0.89	μ CURRENT: 0.87	MAX: 0.87	MIN: 0.87	LEN: 272272	TIME: 3.13
# EP 273	μ LAST 100: 0.88	μ CURRENT: 0.00	MAX: 0.00	MIN: 0.00	LEN: 273273	TIME: 3.12
# EP 274	μ LAST 100: 0.87	μ CURRENT: 0.25	MAX: 0.25	MIN: 0.25	LEN: 274274	TIME: 3.14
# EP 275	μ LAST 100: 0.87	μ CURRENT: 0.56	MAX: 0.56	MIN: 0.56	LEN: 275275	TIME: 3.15
# EP 276	μ LAST 100: 0.87	μ CURRENT: 1.24	MAX: 1.24	MIN: 1.24	LEN: 276276	TIME: 3.16
# EP 277	μ LAST 100: 0.89	μ CURRENT: 1.30	MAX: 1.30	MIN: 1.30	LEN: 277277	TIME: 3.16
# EP 278	μ LAST 100: 0.90	μ CURRENT: 1.74	MAX: 1.74	MIN: 1.74	LEN: 278278	TIME: 3.16
# EP 279	μ LAST 100: 0.90	μ CURRENT: 1.73	MAX: 1.73	MIN: 1.73	LEN: 279279	TIME: 3.14
# EP 280	μ LAST 100: 0.90	μ CURRENT: 0.08	MAX: 0.08	MIN: 0.08	LEN: 280280	TIME: 3.14
# EP 281	μ LAST 100: 0.91	μ CURRENT: 2.12	MAX: 2.12	MIN: 2.12	LEN: 281281	TIME: 3.14
# EP 282	μ LAST 100: 0.93	μ CURRENT: 2.53	MAX: 2.53	MIN: 2.53	LEN: 282282	TIME: 3.15
# EP 283	μ LAST 100: 0.94	μ CURRENT: 0.75	MAX: 0.75	MIN: 0.75	LEN: 283283	TIME: 3.14
# EP 284	μ LAST 100: 0.95	μ CURRENT: 2.37	MAX: 2.37	MIN: 2.37	LEN: 284284	TIME: 3.16
# EP 285	μ LAST 100: 0.94	μ CURRENT: 0.12	MAX: 0.12	MIN: 0.12	LEN: 285285	TIME: 3.14
# EP 286	μ LAST 100: 0.92	μ CURRENT: 0.52	MAX: 0.52	MIN: 0.52	LEN: 286286	TIME: 3.13
# EP 287	μ LAST 100: 0.93	μ CURRENT: 1.17	MAX: 1.17	MIN: 1.17	LEN: 287287	TIME: 3.14
# EP 288	μ LAST 100: 0.92	μ CURRENT: 0.84	MAX: 0.84	MIN: 0.84	LEN: 288288	TIME: 3.13
# EP 289	μ LAST 100: 0.92	μ CURRENT: 0.30	MAX: 0.30	MIN: 0.30	LEN: 289289	TIME: 3.13
# EP 290	μ LAST 100: 0.93	μ CURRENT: 1.68	MAX: 1.68	MIN: 1.68	LEN: 290290	TIME: 3.14
# EP 291	μ LAST 100: 0.94	μ CURRENT: 3.15	MAX: 3.15	MIN: 3.15	LEN: 291291	TIME: 3.14
# EP 292	μ LAST 100: 0.95	μ CURRENT: 1.59	MAX: 1.59	MIN: 1.59	LEN: 292292	TIME: 3.13
# EP 293	μ LAST 100: 0.94	μ CURRENT: 1.52	MAX: 1.52	MIN: 1.52	LEN: 293293	TIME: 3.10
# EP 294	μ LAST 100: 0.95	μ CURRENT: 1.97	MAX: 1.97	MIN: 1.97	LEN: 294294	TIME: 3.12
# EP 295	μ LAST 100: 0.97	μ CURRENT: 2.59	MAX: 2.59	MIN: 2.59	LEN: 295295	TIME: 3.13
# EP 296	μ LAST 100: 0.97	μ CURRENT: 0.35	MAX: 0.35	MIN: 0.35	LEN: 296296	TIME: 3.13
# EP 297	μ LAST 100: 0.97	μ CURRENT: 0.23	MAX: 0.23	MIN: 0.23	LEN: 297297	TIME: 3.14
# EP 298	μ LAST 100: 0.98	μ CURRENT: 1.54	MAX: 1.54	MIN: 1.54	LEN: 298298	TIME: 3.13
# EP 299	μ LAST 100: 0.98	μ CURRENT: 1.18	MAX: 1.18	MIN: 1.18	LEN: 299299	TIME: 3.15
# EP 300	μ LAST 100: 0.98	μ CURRENT: 1.28	MAX: 1.28	MIN: 1.28	LEN: 300300	TIME: 3.17
#
# Solved in 16.02 minutes.

# %% [markdown]
# #### Plot the Results

# %%
# Plot the scores using matplotlib.
plt.style.use('ggplot')

fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)
plt.title('Rewards - Using DDPG')
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.legend(('Score'), fontsize='xx-large')

# Reveal the plot.
plt.show()

# %% [markdown]
# #### We're Finished!

# %%
env.close()
